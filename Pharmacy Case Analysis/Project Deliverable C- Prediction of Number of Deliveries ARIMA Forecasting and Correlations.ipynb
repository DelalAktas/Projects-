# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

print('numpy version:', np.__version__)
print('matplotlib version:', pd.__version__)

#read csv file
df1 = pd.read_csv('C:/Users/Bilal Aktas/Desktop/Git Lab/Fontys/Fontys Subjects/Semester 4/Applied Data Science A/Project/Dataset/ds.csv', header=None)
df2 = pd.read_csv('C:/Users/Bilal Aktas/Desktop/Git Lab/Fontys/Fontys Subjects/Semester 4/Applied Data Science A/Project/Dataset/ds2020.csv', header=None)

#df = pd.read_csv ('C:/Users/Bilal Aktas/Desktop/CleanedDataset.csv')
# Out:
# numpy version: 1.19.2
# matplotlib version: 1.1.5

# %%
index = df1.index
number_of_rows = len(index)

# %%
print(number_of_rows)
# Out:
# 22705348

# %%
#add columns
df1.columns = ['Delivery date', 'Delivery time', 'Pharmacy number', 'Pharmacy Postcode (2)', 'Year of birth', 
              'Gender', 'CNK', 'Product name', 'ATC code', 'Units', 'Price', 'Contribution']
df2.columns = ['Delivery date', 'Delivery time', 'Pharmacy number', 'Pharmacy Postcode (2)', 'Year of birth', 
              'Gender', 'CNK', 'Product name', 'ATC code', 'Units', 'Price', 'Contribution']

# %%
#check dataframe
df1.head(5)
# Out:
#   Delivery date Delivery time  Pharmacy number  Pharmacy Postcode (2)  \
# 0    01/01/2017         00:00          7341765                     21
# 1    01/01/2017         00:00          7341765                     21
# 2    01/01/2017         00:00          7341765                     21
# 3    01/01/2017         00:00          8272695                     16
# 4    01/01/2017         00:00          8272695                     16
#
#    Year of birth  Gender      CNK                            Product name  \
# 0           1924       1  1715119   AMOXICLAV SANDOZ 500MG/125 MG COMP 30
# 1           1922       1  5520523                         WACHTHONORARIUM
# 2           1925       1  1799931  ZALDIAR 37,5 MG/325 MG FILMOMH TABL 20
# 3           1932       2  1719400          VASEXTEN CAPS BLIST 28 X 10 MG
# 4           1933       2  5520523                         WACHTHONORARIUM
#
#   ATC code  Units  Price  Contribution
# 0  J01CR02     30  14.81          3.47
# ...

# %%
df1.count()
# Out:
# Delivery date            22705348
# Delivery time            17764167
# Pharmacy number          22705348
# Pharmacy Postcode (2)    22705348
# Year of birth            22705348
# Gender                   22705348
# CNK                      22705348
# Product name             22705348
# ATC code                 22705348
# Units                    22705348
# Price                    22705348
# Contribution             22705348
# dtype: int64

# %%
#gives information of dataframe
df1.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22705348 entries, 0 to 22705347
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count     Dtype
# ---  ------                 --------------     -----
#  0   Delivery date          22705348 non-null  object
#  1   Delivery time          17764167 non-null  object
#  2   Pharmacy number        22705348 non-null  int64
#  3   Pharmacy Postcode (2)  22705348 non-null  int64
#  4   Year of birth          22705348 non-null  int64
#  5   Gender                 22705348 non-null  int64
#  6   CNK                    22705348 non-null  int64
#  7   Product name           22705348 non-null  object
#  8   ATC code               22705348 non-null  object
#  9   Units                  22705348 non-null  int64
#  10  Price                  22705348 non-null  float64
#  11  Contribution           22705348 non-null  float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 2.0+ GB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5072146 entries, 0 to 5072145
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Delivery date          object
#  1   Delivery time          object
#  2   Pharmacy number        int64
#  3   Pharmacy Postcode (2)  int64
#  4   Year of birth          int64
#  5   Gender                 int64
#  6   CNK                    int64
#  7   Product name           object
#  8   ATC code               object
#  9   Units                  int64
#  10  Price                  float64
#  11  Contribution           float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 464.4+ MB

# %%
#sums all the null values of the columns in the dataframe
df1.isnull().sum()
# Out:
# Delivery date                  0
# Delivery time            4941181
# Pharmacy number                0
# Pharmacy Postcode (2)          0
# Year of birth                  0
# Gender                         0
# CNK                            0
# Product name                   0
# ATC code                       0
# Units                          0
# Price                          0
# Contribution                   0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Delivery date                 0
# Delivery time            972059
# Pharmacy number               0
# Pharmacy Postcode (2)         0
# Year of birth                 0
# Gender                        0
# CNK                           0
# Product name                  0
# ATC code                      0
# Units                         0
# Price                         0
# Contribution                  0
# dtype: int64

# %%
#df.describe()

# %%
df1.isnull().any()
# Out:
# Delivery date            False
# Delivery time             True
# Pharmacy number          False
# Pharmacy Postcode (2)    False
# Year of birth            False
# Gender                   False
# CNK                      False
# Product name             False
# ATC code                 False
# Units                    False
# Price                    False
# Contribution             False
# dtype: bool

# %%
#filling na values in delivery time column with 00:00
TimeNull = df1['Delivery time']
TimeNull.fillna('00:00',inplace=True)

# %%
TimeNull = df2['Delivery time']
TimeNull.fillna('00:00',inplace=True)

# %%
#dropping outliers in gender column
df1 = df1[df1['Gender'] != 0]
df1 = df1[df1['Gender'] != 3]

# %%
df2 = df2[df2['Gender'] != 0]
df2 = df2[df2['Gender'] != 3]

# %%
df1["Gender"].value_counts(sort=True)
# Out:
# 2    13061752
# 1     9565378
# Name: Gender, dtype: int64

# %%
df2["Gender"].value_counts(sort=True)
# Out:
# 2    2856183
# 1    2203711
# Name: Gender, dtype: int64

# %%
#transform into datetime
df1['Delivery date'] = pd.to_datetime(df1['Delivery date'], infer_datetime_format=True)

# %%
df2['Delivery date'] = pd.to_datetime(df2['Delivery date'], infer_datetime_format=True)

# %%
#checking the value which date was both d-m-Y and m-d-Y
rslt_df = df1[df1['Delivery date'] > '2017-01-30'] 
  
print('\nResult dataframe :\n', rslt_df)
# Out:
# Result dataframe :
#           Delivery date Delivery time  Pharmacy number  Pharmacy Postcode (2)  \
# 3102        2018-01-01         00:00          7981002                     30
# 3103        2018-01-01         00:00          7729509                     30
# 3104        2018-01-01         00:00          7729509                     30
# 3105        2018-01-01         00:00          7981002                     30
# 3106        2018-01-01         00:00          7729509                     30
# ...                ...           ...              ...                    ...
# 22705343    2019-12-31         23:56          7068483                     90
# 22705344    2019-12-31         23:56          7068483                     90
# 22705345    2019-12-31         23:56          7068483                     90
# 22705346    2019-12-31         23:56          7068483                     90
# 22705347    2019-12-31         23:56          7068483                     90
#
# ...

# %%
df2.isnull().any()
# Out:
# Delivery date            False
# Delivery time            False
# Pharmacy number          False
# Pharmacy Postcode (2)    False
# Year of birth            False
# Gender                   False
# CNK                      False
# Product name             False
# ATC code                 False
# Units                    False
# Price                    False
# Contribution             False
# dtype: bool

# %%
df1['Delivery date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
df1['Delivery date'].max()
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
df2['Delivery date'].min()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
df2['Delivery date'].max()
# Out:
# Timestamp('2020-12-06 00:00:00')

# %%
df3.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-76f292a6f0ff> in <module>
# ----> 1 df3.tail(10)
#
# NameError: name 'df3' is not defined

# %%
#Change the name of the new set with cleaned dates according to your name! 13/01/2017

#df3.to_csv('CleanedDataset.csv')

# %%
df = df1

# %%
df['ATCShort'] = df['ATC code'].str[:3]
df.head()
# Out:
#   Delivery date Delivery time  Pharmacy number  Pharmacy Postcode (2)  \
# 0    2017-01-01         00:00          7341765                     21
# 1    2017-01-01         00:00          7341765                     21
# 2    2017-01-01         00:00          7341765                     21
# 3    2017-01-01         00:00          8272695                     16
# 4    2017-01-01         00:00          8272695                     16
#
#    Year of birth  Gender      CNK                            Product name  \
# 0           1924       1  1715119   AMOXICLAV SANDOZ 500MG/125 MG COMP 30
# 1           1922       1  5520523                         WACHTHONORARIUM
# 2           1925       1  1799931  ZALDIAR 37,5 MG/325 MG FILMOMH TABL 20
# 3           1932       2  1719400          VASEXTEN CAPS BLIST 28 X 10 MG
# 4           1933       2  5520523                         WACHTHONORARIUM
#
#   ATC code  Units  Price  Contribution ATCShort
# 0  J01CR02     30  14.81          3.47      J01
# ...

# %%
df['Age'] = 2021 -df['Year of birth']

# %%
tempMed = ['A02', 'B01', 'C07','C03','A10']
df['ATCShort'].isin(tempMed)
med_filter = df[df['ATCShort'].isin(tempMed)]

med_filter['ATC_ABB'] = med_filter['ATCShort'].map({'A02': 0, 'B01': 1, 'C07': 2,'C03':3,'A10':4})
# Out:
# <ipython-input-56-0a2ccb5c64bd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   med_filter['ATC_ABB'] = med_filter['ATCShort'].map({'A02': 0, 'B01': 1, 'C07': 2,'C03':3,'A10':4})

# %% [markdown]
# ## Coorelations

# %%
cols = ['Contribution', 'Gender', 'Year of birth', 'Price', 'ATC_ABB','Units']

# %%
import seaborn as sns
cm = np.corrcoef(med_filter[cols].values, rowvar=0)
sns.set(font_scale=1)
hm = sns.heatmap(cm,
    cbar=True,
    annot=True,
    square=True,
    fmt='.2f',
    annot_kws={'size': 10},
    yticklabels=cols,
    xticklabels=cols)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics

X = med_filter[['Contribution', 'Price']]
y = med_filter['ATC_ABB']
print('types:', med_filter['ATC_ABB'].unique())

scaler = StandardScaler().fit(X)
X = scaler.transform(X)
print('The length of X: {}'.format(len(X)))

plt.scatter(X[:,0], X[:,1], edgecolors='k', c=y)
# Out:
# types: [1 0 4 2 3]
# The length of X: 7708128

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = med_filter[['Contribution']].values
Y = med_filter['Price'].values

slr = LinearRegression()
slr.fit(X, Y)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: 7.197
# Intercept: 3.900

# %%
# Plotting a scatter graph with a linear line superimposed on it.
def lin_regplot(X, Y, model):
    plt.scatter(X, Y, c='purple')
    plt.plot(X, model.predict(X), color='red')    
    return None

lin_regplot(X, Y, slr)
plt.xlabel('Contribution')
plt.ylabel('Price')
plt.show()

# %%
X = med_filter[['Contribution']].values
Y = med_filter['ATC_ABB'].values

slr = LinearRegression()
slr.fit(X, Y)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: -0.207
# Intercept: 2.350

# %%
def lin_regplot(X, Y, model):
    plt.scatter(X, Y, c='green')
    plt.plot(X, model.predict(X), color='red')    
    return None

lin_regplot(X, Y, slr)
plt.xlabel('Contribution')
plt.ylabel('ATC')
plt.show()

# %%
def lin_regplot(X, Y, model):
    plt.scatter(X, Y, c='blue')
    plt.plot(X, model.predict(X), color='red')    
    return None

lin_regplot(X, Y, slr)
plt.xlabel('Contribution')
plt.ylabel('Year of birth')
plt.show()

# %%
X = med_filter[['Age']].values
Y = med_filter['Price'].values

slr = LinearRegression()
slr.fit(X, Y)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: -0.104
# Intercept: 28.680

# %%
df.head()
# Out:
#   Delivery date Delivery time  Pharmacy number  Pharmacy Postcode (2)  \
# 0    2017-01-01         00:00          7341765                     21
# 1    2017-01-01         00:00          7341765                     21
# 2    2017-01-01         00:00          7341765                     21
# 3    2017-01-01         00:00          8272695                     16
# 4    2017-01-01         00:00          8272695                     16
#
#    Year of birth  Gender      CNK                            Product name  \
# 0           1924       1  1715119   AMOXICLAV SANDOZ 500MG/125 MG COMP 30
# 1           1922       1  5520523                         WACHTHONORARIUM
# 2           1925       1  1799931  ZALDIAR 37,5 MG/325 MG FILMOMH TABL 20
# 3           1932       2  1719400          VASEXTEN CAPS BLIST 28 X 10 MG
# 4           1933       2  5520523                         WACHTHONORARIUM
#
#   ATC code  Units  Price  Contribution ATCShort  Age
# ...

# %%
def lin_regplot(X, Y, model):
    plt.scatter(X, Y, c='blue')
    plt.plot(X, model.predict(X), color='red')    
    return None

lin_regplot(X, Y, slr)
plt.xlabel('Price')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
cols = ['Contribution', 'Gender', 'Year of birth', 'Price', 'ATC_ABB','Age']
cm = np.corrcoef(med_filter[cols].values, rowvar=0)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm,
    cbar=True,
    annot=True,
    square=True,
    fmt='.2f',
    annot_kws={'size': 15},
    yticklabels=cols,
    xticklabels=cols)
plt.show()

# %%
df_Other = df.groupby('Delivery date')['Price'].sum().reset_index()

# %%
df_Other = df.set_index('Delivery date')

# %%
df_Other.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-01', '2017-01-01', '2017-01-01',
#                '2017-01-01', '2017-01-01', '2017-01-01', '2017-01-01',
#                '2017-01-01', '2017-01-01',
#                ...
#                '2020-07-31', '2020-07-31', '2020-07-31', '2020-07-31',
#                '2020-07-31', '2020-07-31', '2020-07-31', '2020-07-31',
#                '2020-07-31', '2020-07-31'],
#               dtype='datetime64[ns]', name='Delivery date', length=27687024, freq=None)

# %%
y = df_Other['Price'].resample('MS').mean()

# %%
y['2019']
# Out:
# Delivery date
# 2019-01-01    25.129370
# 2019-02-01    24.838848
# 2019-03-01    26.165641
# 2019-04-01    25.085708
# 2019-05-01    26.739781
# 2019-06-01    25.841858
# 2019-07-01    25.953933
# 2019-08-01    25.800736
# 2019-09-01    25.273150
# 2019-10-01    25.286767
# 2019-11-01    25.485720
# 2019-12-01    25.678642
# Freq: MS, Name: Price, dtype: float64

# %%
y.drop(y.tail(3).index,inplace=True)
y['2019':]
# Out:
# Delivery date
# 2019-01-01    25.129370
# 2019-02-01    24.838848
# 2019-03-01    26.165641
# 2019-04-01    25.085708
# 2019-05-01    26.739781
# 2019-06-01    25.841858
# 2019-07-01    25.953933
# 2019-08-01    25.800736
# 2019-09-01    25.273150
# 2019-10-01    25.286767
# 2019-11-01    25.485720
# 2019-12-01    25.678642
# 2020-01-01    28.081156
# 2020-02-01    26.811296
# 2020-03-01    27.510649
# 2020-04-01    29.025445
# 2020-05-01    31.795431
# 2020-06-01    27.796632
# 2020-07-01    30.111412
# 2020-08-01    26.637277
# 2020-09-01    32.781958
# Freq: MS, Name: Price, dtype: float64

# %%
y.plot(figsize=(15,6))
plt.show()

# %%
from pylab import rcParams
import statsmodels.api as sm 
rcParams['figure.figsize'] =18,8

decomposition = sm.tsa.seasonal_decompose(y, model ='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# p = d = q = range(0,2)
# pdq = list(itertools.product(p,d,q))
# seasonal_pdq = [(x[0],x[1],x[2],12) for x in list(itertools.product(p,d,q))]
#
# print('Examples of parameter combinations for Seasonal ARIMA...')
# print('')

# %% [markdown]
# ## General Sales

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Price'].sum().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y = df['Price'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
import warnings
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1022.1062527278989
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1669.5937413616173
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:557.8896503059166
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:263.83762607008487
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:582.6175666412214
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:558.2592920036124
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:285.37396830275355
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:263.94202997720527
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:970.3704417403968
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:627.529097110176
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:530.7977655419872
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:241.97310593647515
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:681.2104534743221
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:626.9152653028805
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:286.98868229255294
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:239.15138636949118
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:830.8477730406092
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1,1,1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3920      2.718     -0.144      0.885      -5.719       4.935
# ma.L1         -0.8313      2.598     -0.320      0.749      -5.924       4.261
# ar.S.L12      -0.1782      7.227     -0.025      0.980     -14.344      13.987
# ma.S.L12       0.3205      4.719      0.068      0.946      -8.929       9.570
# sigma2       1.47e+09      3e-08   4.89e+16      0.000    1.47e+09    1.47e+09
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2016':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=20)
ax.set_ylabel('Sales [EUR] ',fontsize=15)
ax.set_title('The Amount of Sales in Belgium ',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 806474677.76

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 28398.5

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=20)
ax.set_ylabel('Sales [EUR] ',fontsize=15)
ax.set_title('The Amount of Sales in Belgium ',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # General number of deliveries

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATC code'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['ATC code'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:796.9846127538256
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:501.91054772205365
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:401.11092678782484
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:189.46834649230865
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:420.68695790640993
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:406.21095313702233
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:205.40541272135468
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:191.46735082155075
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:751.5882276761026
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:502.1436459959544
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:384.0704588567645
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:168.90863837927586
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:526.7090725784474
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:502.91441873761875
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:200.54200632879656
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:173.98017752986672
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:613.2624790080138
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4708      0.360     -1.306      0.191      -1.177       0.236
# ma.L1         -1.1077      0.889     -1.246      0.213      -2.850       0.634
# ma.S.L12      -0.2657      0.407     -0.653      0.513      -1.063       0.531
# sigma2      6.171e+05   4.69e+05      1.316      0.188   -3.02e+05    1.54e+06
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=20)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of Deliveries in Belgium',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 1578690.99

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 1256.46

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=20)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries in Belgium',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Particular ATC

# %% [markdown]
# ### A02

# %%
df =df.loc[(df["ATCShort"]=="A02")]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATCShort'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['ATCShort'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:607.8182075671685
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:382.24475400712254
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:293.730244245792
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:132.99707432257728
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:299.12412579653096
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:289.744637336366
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:144.32168185105755
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:134.9792944958555
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:549.3767718686698
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:342.5701390216446
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:278.252110281777
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:122.01535787110556
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:298.9501240724612
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:278.33220121675265
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:143.84346362640392
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:121.6875941726721
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:421.6213177311869
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7889      0.286     -2.760      0.006      -1.349      -0.229
# ma.S.L12      -0.0195      0.392     -0.050      0.960      -0.789       0.750
# sigma2      8616.9845   5232.338      1.647      0.100   -1638.210    1.89e+04
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title ('Number of deliveries of medicine for acid related disorders',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 8704.69

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 93.3

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of medicine for acid related disorders',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### B01

# %%
df =df.loc[(df["ATCShort"]=="B01")]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATCShort'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y = df['ATCShort'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:592.8407609068549
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:372.1459070535509
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:274.52151721838857
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:133.38836347893087
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:285.7336829900679
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:277.2810728349195
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:144.30209001167944
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:133.06862047170438
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:534.8655307433407
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:332.8090257745178
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:264.0778095737382
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:123.98002819153454
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:288.06935040019346
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:266.8560783625468
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:146.11293895564
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:124.00117150211943
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:402.50746832132603
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0,1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8459      0.286     -2.963      0.003      -1.405      -0.286
# ma.S.L12      -0.2379      0.506     -0.470      0.638      -1.229       0.753
# sigma2      4340.4020   2672.965      1.624      0.104    -898.512    9579.316
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2016':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title ('Number of deliveries of antithrombotic agents',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 5993.25

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 77.42

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='dodgerblue',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='r',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of antithrombotic agents',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### C07

# %%
df =df.loc[(df["ATCShort"]=="C07")]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATCShort'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y = df['ATCShort'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
import warnings 
warnings.filterwarnings("ignore")
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:606.8591911391698
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:379.67271530696775
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:276.98083138274154
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:132.58143326439622
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:289.75488668572564
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:280.54985457685746
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:143.23012003532725
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:134.25331125086115
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:547.7647815447606
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:339.79248996823287
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:266.12881164721006
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:122.14235229412053
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:291.06368617759404
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:270.20477382981124
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:144.24970420084227
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:123.29292895602283
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:414.51510895085096
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1,1,1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5432      0.848     -0.640      0.522      -2.206       1.120
# ma.L1         -1.0000      2.855     -0.350      0.726      -6.595       4.595
# ar.S.L12      -0.0160      0.196     -0.082      0.935      -0.400       0.368
# ma.S.L12      -0.1819      1.541     -0.118      0.906      -3.202       2.838
# sigma2      2996.6046      0.001   3.15e+06      0.000    2996.603    2996.606
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2016':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title ('Number of deliveries of beta blocking agents',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 6501.28

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 80.63

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='dodgerblue',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='r',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of beta blocking agents',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### C03

# %%
df =df.loc[(df["ATCShort"]=="C03")]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATCShort'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y = df['ATCShort'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:560.1580946051184
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:354.58814214856443
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:252.3425984922017
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:122.96977382870759
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:263.4237298508177
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:253.6702019867162
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:132.8970465924493
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:123.71610516246568
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:504.7069721818069
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:317.028878883624
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:242.74570474500123
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:114.07130296148236
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:265.64265511510774
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:243.56035119530594
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:134.8106521201137
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:115.27201258414789
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:370.3738641846471
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1,1,1),
                                seasonal_order=(0,1,1,12 ),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4725      0.529     -0.893      0.372      -1.509       0.564
# ma.L1         -1.0000   3482.316     -0.000      1.000   -6826.215    6824.215
# ma.S.L12      -1.0001   3482.113     -0.000      1.000   -6825.817    6823.817
# sigma2      1306.1668      1.128   1157.827      0.000    1303.956    1308.378
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2016':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of diuretic medicines',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 3552.26

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 59.6

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='dodgerblue',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='r',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of diuretic medicines',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### A10

# %%
df =df.loc[(df["ATCShort"]=="A10")]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['ATCShort'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y = df['ATCShort'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:595.3166395819993
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:375.3642262037889
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:278.7045915889768
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:129.10159742844596
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:287.6586652973614
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:276.9969746980637
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:140.78081903319753
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:129.98818294230415
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:537.1083462288468
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:335.3420725080202
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:265.00605269363604
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:119.45662258544519
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:287.9056120513402
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:264.5679085822349
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:142.72012738624628
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:120.7599438337709
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:409.52674822024994
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0,1,1),
                                seasonal_order=(0,1,1,12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0000      0.696     -1.437      0.151      -2.364       0.364
# ma.S.L12      -0.0582      0.221     -0.264      0.792      -0.491       0.375
# sigma2      3922.3870      0.000   2.21e+07      0.000    3922.387    3922.387
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2016':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 4))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of medicines used in Diabets',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 3929.04

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 62.68

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries of medicines used in Diabets',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Specific location Forecasting

# %% [markdown]
# ## Brussels

# %%
df=df1

# %%
df =df.loc[(df["Pharmacy Postcode (2)"] >=10) & (df["Pharmacy Postcode (2)"] <=12)]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Product name'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['Product name'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:680.698136543773
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:431.46321141713315
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:340.3445947531225
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:158.66210430214826
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:357.70488885680453
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:343.9808034453286
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:171.895556230184
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:160.3370881042844
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:619.2352419470219
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:387.04865916597333
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:327.69623578898603
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:146.01173681502004
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5763      0.386     -1.494      0.135      -1.332       0.180
# ma.L1         -0.9051      0.125     -7.241      0.000      -1.150      -0.660
# ma.S.L12      -0.3171      0.369     -0.860      0.390      -1.040       0.406
# sigma2      2.749e+04   1.99e+04      1.382      0.167   -1.15e+04    6.65e+04
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Brussels area',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 149795.29

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 387.03

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Brussels area',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Antwerp

# %%
df=df1

# %%
df =df.loc[(df["Pharmacy Postcode (2)"] >=20) & (df["Pharmacy Postcode (2)"] <=29)]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Product name'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['Product name'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:720.6748106253616
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:459.600107730842
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:356.35990644375244
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:166.56539788287816
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:374.65278795606133
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:359.51341499996323
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:180.8651570099261
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:168.0216850111749
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:677.4362668209106
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:411.17782480460676
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:338.107912268775
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:153.48088665029408
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0000      0.716     -1.396      0.163      -2.404       0.404
# ar.S.L12      -0.0237      0.291     -0.082      0.935      -0.593       0.546
# ma.S.L12      -0.3019      0.744     -0.406      0.685      -1.761       1.157
# sigma2      1.567e+05   4.57e-06   3.43e+10      0.000    1.57e+05    1.57e+05
# ...

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Antwerp area',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 163182.23

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 403.96

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Antwerp area',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Luxembourg Area

# %%
df=df1

# %%
df =df.loc[(df["Pharmacy Postcode (2)"] >=66) & (df["Pharmacy Postcode (2)"] <=69)]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Product name'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['Product name'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:492.85359235522037
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:312.88461675307315
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:216.39880006994744
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:94.45584037543654
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:225.30003597410087
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:211.9394914759077
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:101.94805955694162
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:96.45590779616711
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:439.6066960294487
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:277.22235985466875
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:200.89057576028603
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:81.84434389502306
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 0, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5084      0.193     -2.629      0.009      -0.888      -0.129
# ma.S.L12      -1.0000   4757.255     -0.000      1.000   -9325.048    9323.048
# sigma2        76.2745   3.63e+05      0.000      1.000   -7.11e+05    7.11e+05
# ...
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Luxembourg area',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 328.95

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 18.14

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Luxembourg area',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Flemish Region

# %%
df=df1

# %%
df =df.loc[(df["Pharmacy Postcode (2)"] >=30) & (df["Pharmacy Postcode (2)"] <=34)]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Product name'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['Product name'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:618.0467478488881
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:383.61793411719333
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:308.20244665590764
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:152.76189398629234
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:317.25912955391726
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:300.62310740221625
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:164.86411706664006
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:150.55556771344112
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:558.6698978946073
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:345.45691703085305
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:294.33410366647564
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:139.71605729907606
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6240      0.658     -0.948      0.343      -1.914       0.666
# ma.L1         -0.3422      0.860     -0.398      0.691      -2.027       1.343
# ma.S.L12      -1.0011    562.727     -0.002      0.999   -1103.926    1101.924
# sigma2      8512.8769   4.79e+06      0.002      0.999   -9.38e+06     9.4e+06
# ...
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries ',fontsize=15)
ax.set_title('Number of deliveries in Flemish area',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 15729.05

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 125.42

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='dodgerblue',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='r',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries in Flemish area',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Waloon Region

# %%
df=df1

# %%
df =df.loc[(df["Pharmacy Postcode (2)"] >=13) & (df["Pharmacy Postcode (2)"] <=14)]

# %%
df = df.sort_values('Delivery date')

# %%
df = df.groupby('Delivery date')['Product name'].count().reset_index()

# %%
df = df.set_index('Delivery date')

# %%
y= df['Product name'].resample('MS').mean()

# %%
import itertools
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:516.1988627719727
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:331.1491553757075
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:252.15294604286257
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:109.7316418682494
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:253.20224167578613
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:242.5535833632053
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:120.35135240636349
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:111.23757523426416
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:463.3096126184648
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:293.2075842532061
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:231.2857368087276
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:94.4517746557869
# ...

# %%
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6579      0.335     -1.964      0.050      -1.315      -0.001
# ma.S.L12      -0.2066      0.151     -1.366      0.172      -0.503       0.090
# sigma2       350.4579    208.243      1.683      0.092     -57.691     758.606
# ...
# c:\users\bilal aktas\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
pred = results.get_prediction(start=pd.to_datetime('2018-12-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2013':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
 pred_ci.iloc[:, 0],
 pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries in Wallon Region',fontsize=20)
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2018-12-01':]
# Compute the mean squared error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 247.64

# %%
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 15.74

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='Observed', figsize=(20, 10),color='r',linewidth=6)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast',color='dodgerblue',linewidth=6)
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Number of deliveries',fontsize=15)
ax.set_title('Number of deliveries in Wallon Region',fontsize=20)
plt.legend()
plt.show()
